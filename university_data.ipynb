# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Assignment: The university dataset (You may work solo or with one other person. Each person should have their own github repo with the completed assignment when you are done.)
# Load the university dataset (link below) into a pandas dataframe.
# Using pandas, find both the mean and median size by each university type (as given in the dataframe), ordered by average size in ascending order.
# Make new columns  in the dataframe from existing data for the following attributes:
# City
# State
# ZipCode
# Private or Public
# for-profit or not-for-profit
# primarily associate's (1 for Yes, 0 for No)
#  Using the new columns you've made above (and excluding the original type column), find both the mean and median size of each university by State, by Private or Public, and by whether the university is primarily associate's or not.
# Use the tools you've learned to compute at **least** one other aggregate from the dataset
# Save the updated dataframe as a csv  (using the pandas to_csv method) and commit your files, and push up to github.
# (Note: Make a new git repo on your computer and a new github repo in the cloud for this assignment. Save, commit and push often!!!
# Git and github are now a part of your workflow. You must use them for every assignment/project that you do, whether I explicitly tell you to or not, now and forever. )
# https://s3-us-west-2.amazonaws.com/learn-assets.galvanize.com/gSchool/ds-curriculum/sql-block/universities.csv (edited) (edited)

# %%
University = pd.read_csv('C:\\Users\\naror\\Downloads\\universities.csv')

# %%
University.head()
# Out:
#                                       name  \
# 0  A T Still University of Health Sciences
# 1             Abilene Christian University
# 2     Abraham Baldwin Agricultural College
# 3                          Academy College
# 4     Academy for Five Element Acupuncture
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# 3  1101 E. 78th Street, Suite 100, Minneapolis, M...  www.academycollege.edu
# 4         305 SE 2nd Ave, Gainesville, Florida 32601   www.acupuncturist.edu
#
#                                                 Type    Size
# 0                     4-year, Private not-for-profit  3480.0
# 1                     4-year, Private not-for-profit  4669.0
# ...

# %%
University
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
agg = University.groupby('Type')

# %%
agg

# %%
University
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
University.agg
# Out:
# <bound method DataFrame.aggregate of                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# ...

# %%
University.sort_values('Type')
# Out:
#                                                 name  \
# 2587          University of Phoenix-San Diego Campus
# 2592  University of Phoenix-Southern Colorado Campus
# 2593       University of Phoenix-Springfield  Campus
# 2594           University of Phoenix-St Louis Campus
# 2595              University of Phoenix-Tulsa Campus
# ...                                              ...
# 2785         West Virginia University at Parkersburg
# 2006                            Sitting Bull College
# 212                                 Bellevue College
# 586         CUNY New York City College of Technology
# 984                       Indian River State College
#
#                                                 address  \
# 2587  3890 Murphy Canyon Road Suite 100, San Diego, ...
# 2592  5725 Mark Dabling Blvd., Colorado Springs, Col...
# 2593  1343 E. Kingsley Street, Springfield, Missouri...
# 2594  13801 Riverport Drive, Ste. 102, Saint Louis, ...
# ...

# %%
University
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
u-type = University.sort_values('Type')
# Out:
#   File "<ipython-input-13-a09a52489b2a>", line 1
#     u-type = University.sort_values('Type')
#                                            ^
# SyntaxError: can't assign to operator

# %%
utype = University.sort_values('Type')

# %%
utype
# Out:
#                                                 name  \
# 2587          University of Phoenix-San Diego Campus
# 2592  University of Phoenix-Southern Colorado Campus
# 2593       University of Phoenix-Springfield  Campus
# 2594           University of Phoenix-St Louis Campus
# 2595              University of Phoenix-Tulsa Campus
# ...                                              ...
# 2785         West Virginia University at Parkersburg
# 2006                            Sitting Bull College
# 212                                 Bellevue College
# 586         CUNY New York City College of Technology
# 984                       Indian River State College
#
#                                                 address  \
# 2587  3890 Murphy Canyon Road Suite 100, San Diego, ...
# 2592  5725 Mark Dabling Blvd., Colorado Springs, Col...
# 2593  1343 E. Kingsley Street, Springfield, Missouri...
# 2594  13801 Riverport Drive, Ste. 102, Saint Louis, ...
# ...

# %%
utype.mean('Size')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f38258c8418d> in <module>
# ----> 1 utype.mean('Size')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11215             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11216         return self._reduce(
# > 11217             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11218         )
#   11219
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7858         else:
#    7859             # TODO: Make other agg func handle axis=None properly
# -> 7860             axis = self._get_axis_number(axis)
#    7861             labels = self._get_agg_axis(axis)
#    7862             constructor = self._constructor
#
# ...

# %%
University.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
utype.mean()
# Out:
# Size    4374.88123
# dtype: float64

# %%
University.mean()
# Out:
# Size    4374.88123
# dtype: float64

# %%
University.groupby('Type').mean()
# Out:
#                                                             Size
# Type
# 4-year, Private for-profit                           3504.501859
# 4-year, Private not-for-profit                       2399.885696
# 4-year, Public                                      11478.913765
# 4-year, primarily associate's, Private for-profit     934.380597
# 4-year, primarily associate's, Private not-for-...   1129.413793
# 4-year, primarily associate's, Public                6889.366197

# %%
University.mean()
# Out:
#                                                             Size
# Type
# 4-year, Private for-profit                           3504.501859
# 4-year, Private not-for-profit                       2399.885696
# 4-year, Public                                      11478.913765
# 4-year, primarily associate's, Private for-profit     934.380597
# 4-year, primarily associate's, Private not-for-...   1129.413793
# 4-year, primarily associate's, Public                6889.366197

# %%
utype
# Out:
#                                                 name  \
# 2587          University of Phoenix-San Diego Campus
# 2592  University of Phoenix-Southern Colorado Campus
# 2593       University of Phoenix-Springfield  Campus
# 2594           University of Phoenix-St Louis Campus
# 2595              University of Phoenix-Tulsa Campus
# ...                                              ...
# 2785         West Virginia University at Parkersburg
# 2006                            Sitting Bull College
# 212                                 Bellevue College
# 586         CUNY New York City College of Technology
# 984                       Indian River State College
#
#                                                 address  \
# 2587  3890 Murphy Canyon Road Suite 100, San Diego, ...
# 2592  5725 Mark Dabling Blvd., Colorado Springs, Col...
# 2593  1343 E. Kingsley Street, Springfield, Missouri...
# 2594  13801 Riverport Drive, Ste. 102, Saint Louis, ...
# ...

# %%
utype.mean()
# Out:
# Size    4374.88123
# dtype: float64

# %%
utype.groupby('Type').mean()
# Out:
#                                                             Size
# Type
# 4-year, Private for-profit                           3504.501859
# 4-year, Private not-for-profit                       2399.885696
# 4-year, Public                                      11478.913765
# 4-year, primarily associate's, Private for-profit     934.380597
# 4-year, primarily associate's, Private not-for-...   1129.413793
# 4-year, primarily associate's, Public                6889.366197

# %%
utype.groupby('Type').median()
# Out:
#                                                       Size
# Type
# 4-year, Private for-profit                           730.0
# 4-year, Private not-for-profit                      1206.0
# 4-year, Public                                      7669.0
# 4-year, primarily associate's, Private for-profit    564.5
# 4-year, primarily associate's, Private not-for-...   768.0
# 4-year, primarily associate's, Public               3558.0
